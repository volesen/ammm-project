# %%
import os
import re

OBJECTIVE_PATTERN = re.compile(r'OBJECTIVE: (\d+)')
TIME_PATTERN = re.compile(r"Total \(root\+branch&cut\) =\s+(\d+\.\d+) sec.")

# %%
results = []

for filename in os.listdir("../reference-benchmarks"):
    if not filename.endswith(".out"):
        continue

    name, _ = os.path.splitext(filename)

    solver, instance = name.split("-")

    with open(os.path.join("../reference-benchmarks", filename)) as f:
        content = f.read()

    objective_match = OBJECTIVE_PATTERN.search(content)
    if objective_match:
        objective = int(objective_match.group(1))
    else:
        objective = None

    time_match = TIME_PATTERN.search(content)
    if time_match:
        time = float(time_match.group(1))
    else:
        time = None

    results.append((solver, instance, objective, time))

# %%
results
# Out:
# [('bigM', 'project.3', 10, 0.02),
#  ('bigM', 'project.2', 11, 0.02),
#  ('bigM', 'project.0', 8, 0.01),
#  ('bigM', 'project.1', 11, 0.01),
#  ('bigM', 'project.5', 15, 0.03),
#  ('bigM', 'project.4', 16, 924.94),
#  ('bigM', 'project.6', 17, 0.05),
#  ('bigM', 'project.7', 13, 0.12),
#  ('bigM3', 'project.0', 8, 0.0),
#  ('bigM3', 'project.1', 11, 0.01),
#  ('bigM1', 'project.8', 35, 1.04),
#  ('bigM3', 'project.3', 10, 0.0),
#  ('binary', 'project.8', 35, 0.47),
#  ('binary', 'project.9', 26, 4393.87),
#  ('bigM3', 'project.2', 11, 0.01),
#  ('bigM1', 'project.9', 30, 0.18),
#  ('bigM2', 'project.8', 35, 936.89),
#  ('bigM3', 'project.6', 17, 0.01),
#  ('bigM3', 'project.7', 13, 0.04),
#  ('bigM2', 'project.9', 30, 0.2),
#  ('bigM3', 'project.5', 15, 0.01),
#  ('bigM3', 'project.4', 16, 0.01),
#  ('bigM1', 'project.2', 11, 0.01),
#  ('bigM2', 'project.7', 13, 0.03),
#  ('bigM3', 'project.9', 30, 0.18),
#  ('binary', 'project.2', 11, 0.0),
#  ('binary', 'project.3', 10, 0.0),
#  ('bigM3', 'project.8', 35, 0.76),
#  ('bigM2', 'project.6', 17, 0.01),
#  ('bigM1', 'project.3', 10, 0.0),
#  ('bigM1', 'project.1', 11, 0.01),
#  ('bigM2', 'project.4', 16, 0.01),
#  ('binary', 'project.1', 11, 0.0),
#  ('binary', 'project.0', 8, 0.01),
#  ('bigM2', 'project.5', 15, 0.01),
#  ('bigM1', 'project.0', 8, 0.0),
#  ('bigM1', 'project.4', 16, 0.01),
#  ('bigM2', 'project.1', 11, 0.01),
#  ('binary', 'project.4', 16, 0.0),
#  ('binary', 'project.5', 15, 0.0),
#  ('bigM2', 'project.0', 8, 0.0),
#  ('bigM1', 'project.5', 15, 0.01),
#  ('bigM1', 'project.7', 13, 0.04),
#  ('bigM2', 'project.2', 11, 0.01),
#  ('binary', 'project.7', 13, 0.01),
#  ('binary', 'project.6', 17, 0.01),
#  ('bigM2', 'project.3', 10, 0.0),
#  ('bigM1', 'project.6', 17, 0.01),
#  ('bigM', 'project.9', 30, 0.84),
#  ('bigM', 'project.8', 35, 2.12)]

# %%
import pandas as pd

df = pd.DataFrame(results, columns=['solver', 'instance', 'objective', 'time'])
df
# Out:
#     solver   instance  objective     time
# 0     bigM  project.3         10     0.02
# 1     bigM  project.2         11     0.02
# 2     bigM  project.0          8     0.01
# 3     bigM  project.1         11     0.01
# 4     bigM  project.5         15     0.03
# 5     bigM  project.4         16   924.94
# 6     bigM  project.6         17     0.05
# 7     bigM  project.7         13     0.12
# 8    bigM3  project.0          8     0.00
# 9    bigM3  project.1         11     0.01
# 10   bigM1  project.8         35     1.04
# 11   bigM3  project.3         10     0.00
# 12  binary  project.8         35     0.47
# 13  binary  project.9         26  4393.87
# 14   bigM3  project.2         11     0.01
# 15   bigM1  project.9         30     0.18
# 16   bigM2  project.8         35   936.89
# 17   bigM3  project.6         17     0.01
# 18   bigM3  project.7         13     0.04
# 19   bigM2  project.9         30     0.20
# 20   bigM3  project.5         15     0.01
# 21   bigM3  project.4         16     0.01
# 22   bigM1  project.2         11     0.01
# 23   bigM2  project.7         13     0.03
# 24   bigM3  project.9         30     0.18
# 25  binary  project.2         11     0.00
# 26  binary  project.3         10     0.00
# 27   bigM3  project.8         35     0.76
# 28   bigM2  project.6         17     0.01
# 29   bigM1  project.3         10     0.00
# 30   bigM1  project.1         11     0.01
# 31   bigM2  project.4         16     0.01
# 32  binary  project.1         11     0.00
# 33  binary  project.0          8     0.01
# 34   bigM2  project.5         15     0.01
# 35   bigM1  project.0          8     0.00
# 36   bigM1  project.4         16     0.01
# 37   bigM2  project.1         11     0.01
# 38  binary  project.4         16     0.00
# 39  binary  project.5         15     0.00
# 40   bigM2  project.0          8     0.00
# 41   bigM1  project.5         15     0.01
# 42   bigM1  project.7         13     0.04
# 43   bigM2  project.2         11     0.01
# 44  binary  project.7         13     0.01
# 45  binary  project.6         17     0.01
# 46   bigM2  project.3         10     0.00
# 47   bigM1  project.6         17     0.01
# 48    bigM  project.9         30     0.84
# 49    bigM  project.8         35     2.12

# %%
# Pivot the table
df.pivot_table(index=['solver', 'instance'], values=['objective', 'time'])
# Out:
#                   objective     time
# solver instance
# bigM   project.0        8.0     0.01
#        project.1       11.0     0.01
#        project.2       11.0     0.02
#        project.3       10.0     0.02
#        project.4       16.0   924.94
#        project.5       15.0     0.03
#        project.6       17.0     0.05
#        project.7       13.0     0.12
#        project.8       35.0     2.12
#        project.9       30.0     0.84
# bigM1  project.0        8.0     0.00
#        project.1       11.0     0.01
#        project.2       11.0     0.01
#        project.3       10.0     0.00
#        project.4       16.0     0.01
#        project.5       15.0     0.01
#        project.6       17.0     0.01
#        project.7       13.0     0.04
#        project.8       35.0     1.04
#        project.9       30.0     0.18
# bigM2  project.0        8.0     0.00
#        project.1       11.0     0.01
#        project.2       11.0     0.01
#        project.3       10.0     0.00
#        project.4       16.0     0.01
#        project.5       15.0     0.01
#        project.6       17.0     0.01
#        project.7       13.0     0.03
#        project.8       35.0   936.89
#        project.9       30.0     0.20
# bigM3  project.0        8.0     0.00
#        project.1       11.0     0.01
#        project.2       11.0     0.01
#        project.3       10.0     0.00
#        project.4       16.0     0.01
#        project.5       15.0     0.01
#        project.6       17.0     0.01
#        project.7       13.0     0.04
#        project.8       35.0     0.76
#        project.9       30.0     0.18
# binary project.0        8.0     0.01
#        project.1       11.0     0.00
#        project.2       11.0     0.00
#        project.3       10.0     0.00
#        project.4       16.0     0.00
#        project.5       15.0     0.00
#        project.6       17.0     0.01
#        project.7       13.0     0.01
#        project.8       35.0     0.47
#        project.9       26.0  4393.87

# %%
# Pivot the table
df.pivot_table(index=['instance', 'solver'], values=['objective', 'time'])#.reset_index()
# Out:
#                   objective     time
# instance  solver
# project.0 bigM          8.0     0.01
#           bigM1         8.0     0.00
#           bigM2         8.0     0.00
#           bigM3         8.0     0.00
#           binary        8.0     0.01
# project.1 bigM         11.0     0.01
#           bigM1        11.0     0.01
#           bigM2        11.0     0.01
#           bigM3        11.0     0.01
#           binary       11.0     0.00
# project.2 bigM         11.0     0.02
#           bigM1        11.0     0.01
#           bigM2        11.0     0.01
#           bigM3        11.0     0.01
#           binary       11.0     0.00
# project.3 bigM         10.0     0.02
#           bigM1        10.0     0.00
#           bigM2        10.0     0.00
#           bigM3        10.0     0.00
#           binary       10.0     0.00
# project.4 bigM         16.0   924.94
#           bigM1        16.0     0.01
#           bigM2        16.0     0.01
#           bigM3        16.0     0.01
#           binary       16.0     0.00
# project.5 bigM         15.0     0.03
#           bigM1        15.0     0.01
#           bigM2        15.0     0.01
#           bigM3        15.0     0.01
#           binary       15.0     0.00
# project.6 bigM         17.0     0.05
#           bigM1        17.0     0.01
#           bigM2        17.0     0.01
#           bigM3        17.0     0.01
#           binary       17.0     0.01
# project.7 bigM         13.0     0.12
#           bigM1        13.0     0.04
#           bigM2        13.0     0.03
#           bigM3        13.0     0.04
#           binary       13.0     0.01
# project.8 bigM         35.0     2.12
#           bigM1        35.0     1.04
#           bigM2        35.0   936.89
#           bigM3        35.0     0.76
#           binary       35.0     0.47
# project.9 bigM         30.0     0.84
#           bigM1        30.0     0.18
#           bigM2        30.0     0.20
#           bigM3        30.0     0.18
#           binary       26.0  4393.87

# %%
# Save the table
#df.write_csv('cplex-reference-results.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/zy/scmx42hx4ld8kqbznp6nbwyh0000gn/T/ipykernel_1780/3980495601.py in ?()
#       1 # Save the table
# ----> 2 df.write_csv('cplex-reference-results.csv')
#
# ~/UPC/ammm/ammm-project/.venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'write_csv'
